# %%
### Making the trialbank for the experiment
### Finally fixed the flow/compensator problem now can use all 4 valves
import numpy as np
import pickle
from copy import deepcopy

# %%
bt = pickle.Unpickler(open('base_trialbank.trialbank', 'rb')).load()

# %%
print(bt)
# Out:
# [[9, [{'type': 'Binary', 'onset': 0.0, 'offset': 0.0, 'num_of_bins': 6.0, 'value_to_binarise': 0, 'bin_size': 0.018, 'shatter_frequency': 500.0, 'position': 0, 'isShatter': True, 'shatter_duty': 0.5, 'inversion': False}, {'type': 'Binary', 'onset': 0.0, 'offset': 0.0, 'num_of_bins': 6.0, 'value_to_binarise': 0, 'bin_size': 0.018, 'shatter_frequency': 500.0, 'position': 1, 'isShatter': True, 'shatter_duty': 0.5, 'inversion': False}, {'type': 'Binary', 'onset': 0.0, 'offset': 0.0, 'num_of_bins': 6.0, 'value_to_binarise': 0, 'bin_size': 0.018, 'shatter_frequency': 500.0, 'position': 2, 'isShatter': True, 'shatter_duty': 0.5, 'inversion': False}, {'type': 'Binary', 'onset': 0.0, 'offset': 0.0, 'num_of_bins': 6.0, 'value_to_binarise': 0, 'bin_size': 0.018, 'shatter_frequency': 500.0, 'position': 3, 'isShatter': True, 'shatter_duty': 0.5, 'inversion': False}, {'type': 'Binary', 'onset': 0.0, 'offset': 0.0, 'num_of_bins': 6.0, 'value_to_binarise': 0, 'bin_size': 0.018, 'shatter_frequency': 
# ...

# %%
trialbank = []
for i in range(32):
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 64 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[1]['value_to_binarise'] =i
    base_valves[1]['shatter_duty'] = 0.5
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.65
    trialbank.append([9, base_valves, 'O2_M1_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[0]['value_to_binarise'] =i
    base_valves[0]['shatter_duty'] = 0.2
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.45
    trialbank.append([9, base_valves, 'O1_M1_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 32 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[2]['value_to_binarise'] =i
    base_valves[2]['shatter_duty'] = 0.55
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.6
    trialbank.append([9, base_valves, 'B_M1_%i' % i])
    
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + 64 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[5]['value_to_binarise'] =i
    base_valves[5]['shatter_duty'] = 0.23
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.62
    trialbank.append([9, base_valves, 'O2_M2_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[4]['value_to_binarise'] =i
    base_valves[4]['shatter_duty'] = 0.5
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.37
    trialbank.append([9, base_valves, 'O1_M2_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + 32 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[6]['value_to_binarise'] =i
    base_valves[6]['shatter_duty'] = 0.4
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.4
    trialbank.append([9, base_valves, 'B_M2_%i' % i])

# %%
pickle.dump(trialbank, open('210420_fulltrialbank.trialbank', 'wb'))

# %%
### Update on 210518 for new valve flow measurements

trialbank = []
for i in range(1,32):
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 64 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[1]['value_to_binarise'] =i
    base_valves[1]['shatter_duty'] = 0.75
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.23
    trialbank.append([9, base_valves, 'O2_M1_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[0]['value_to_binarise'] =i
    base_valves[0]['shatter_duty'] = 0.5
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.11
    trialbank.append([9, base_valves, 'O1_M1_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 32 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[2]['value_to_binarise'] =i
    base_valves[2]['shatter_duty'] = 0.55
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.6
    trialbank.append([9, base_valves, 'B_M1_%i' % i])
    
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + 64 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[5]['value_to_binarise'] =i
    base_valves[5]['shatter_duty'] = 0.2
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.68
    trialbank.append([9, base_valves, 'O2_M2_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[4]['value_to_binarise'] =i
    base_valves[4]['shatter_duty'] = 0.4
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.47
    trialbank.append([9, base_valves, 'O1_M2_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + 32 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[6]['value_to_binarise'] =i
    base_valves[6]['shatter_duty'] = 0.4
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.4
    trialbank.append([9, base_valves, 'B_M2_%i' % i])

# %%
pickle.dump(trialbank, open('210518_fulltrialbank.trialbank', 'wb'))

# %%
### Update on 210617 for 2 odour additions and new flow measurements

trialbank = []
for i in range(1,32):
       
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[0]['value_to_binarise'] =i
    base_valves[0]['shatter_duty'] = 0.42
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.25
    trialbank.append([9, base_valves, 'O1_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 64 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[1]['value_to_binarise'] =i
    base_valves[1]['shatter_duty'] = 0.5
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.47
    trialbank.append([9, base_valves, 'O2_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 32 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[2]['value_to_binarise'] =i
    base_valves[2]['shatter_duty'] = 0.55
    base_valves[3]['value_to_binarise'] = i
    base_valves[3]['shatter_duty'] = 0.6
    trialbank.append([9, base_valves, 'B1_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[4]['value_to_binarise'] =i
    base_valves[4]['shatter_duty'] = 0.5
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.35
    trialbank.append([9, base_valves, 'O3_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + 64 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[5]['value_to_binarise'] =i
    base_valves[5]['shatter_duty'] = 0.47
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.27
    trialbank.append([9, base_valves, 'O4_%i' % i])
    
    base_valves = deepcopy(bt[0][1])
    base_valves[-1]['num_of_bins']= 9
    base_valves[-1]['value_to_binarise'] = 256 + 128 + 32 + i
    for j in range(8):
        base_valves[j]['num_of_bins'] = 5
    base_valves[6]['value_to_binarise'] =i
    base_valves[6]['shatter_duty'] = 0.4
    base_valves[7]['value_to_binarise'] = i
    base_valves[7]['shatter_duty'] = 0.5
    trialbank.append([9, base_valves, 'B2_%i' % i])

# %%
pickle.dump(trialbank, open('210617_4_odour_fulltrialbank.trialbank', 'wb'))
